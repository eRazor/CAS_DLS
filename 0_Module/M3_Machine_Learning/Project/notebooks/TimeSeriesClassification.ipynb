# %% [markdown]
# # Project Summary
#
# This notebook shows the application of ml techniques to classify patterns in a multivariate timeseries data.

# %% [markdown]
# ## 1 Source

# %%
## Feature Engineering
1. Segmentation using "landmark" -> 3 consecutive breach of a threshold in the gyro- / accelero-meter (and the optional increase of heart rate as validation)
threshhold is set above the recording of walking

2. Windowed FFT -> if certain frequency is retrieved given a window.

Improve generalization
Shuffle -> requires known start and end of a segment 
Cross_Validation Split

StandardScaler
Sensor Fusion (correlate accelleration and rotation and gravity)
z-normalization
shift heart rate (due to delayed effects vs movements)
auto_feature

Moment representation
Statistical properties over time
->Pattern matching -> costly -> more details better accuracy 
Risk: overfitting

Spectral properties / representation
Fourier Transform (FT): Breaks down a time series into a combination of sine and cosine waves to show what frequencies are present.
Fast Fourier Transform (FFT): A faster version of the Fourier Transform that is widely used in practice.
Periodogram: A plot that shows how much signal energy is present at each frequency. It helps visualize repeating patterns.
Welch’s Method: Improves the periodogram by splitting the data into overlapping parts, averaging them to reduce noise.
Lomb-Scargle Periodogram: A version of the periodogram that works well even when the data is unevenly spaced or has gaps.
Wavelet Transform: Breaks down the time series into both time and frequency components. Good for signals that change over time.
Short-Time Fourier Transform (STFT): Like the Fourier Transform, but applied in small time windows, so it shows how frequencies change over time.


State Space representation
Description of Behaviour as a system over Time


28.12.2025

# %% [markdown]
# ## Grid Search
# Hyperparameters for
# SVM C Value
# Random Forest (prune / max depth)

# %%
## Cross Validation Results
Evaluation after Test Run

100000 Samples / 10

10 Evaluations à
10 -> 8 Training, 2 Test

Random Forest: Tief, 
SVR: C=, 

Decision Tree c=4.5

kNN

# %% [markdown]
# ## Confusion Matrix
