# %% [markdown]
# 1 Hot encoding:
# Number of Features = number of labels -1
#
# Must have Normal Distribution -> Feature Engineeering
# Feature Set!
#
# Feature Scaling -> Give Weight to the features
# Wrong results if data (especially with new data) not scaled
#
# Fit() -> For learning
# Transform -> to Apply (to new data)
