# %% [markdown]
# # Group Work

# %% [markdown]
# ## Implement perceptron performing logical OR gate

# %%
import numpy as np
# define input
# set weights and biases
#compute and print output

# %% [markdown]
# ## Vizualize decision boundary for perceptron learning logical OR gate

# %%
# hint: reuse the code from lecture ;)

# %% [markdown]
# Visualize decision boundary for perceptron learning XOR gate

# %%
# hint: what is the input/output difference when implementing XOR compared to OR?

# %% [markdown]
# ## Implement multilayer perceptron that computes XOR
# ### note: only implement it ans assume step activation function - it is not learning - see exmaple for simple neuron implementation
#
# hint: use simple weignts and biases. i.e. +-1

# %%
# MLP for XOR
# input
X = np.array( ((1,1), (1, 0), (0,1), (0,0)) )

# extended input
X_ext =

# target
T = np.array([0,1,1,0])
print(X)
print(X_ext)

# %%
# Specify a set of predefined weights that allow to implement the XOR function
# Include the biases in the weight arrays

# WEIGHTS/BIAS FOR FIRST NODE IN HIDDEN LAYER
W_h1_init = np.array([???, ???]) # fill in your weights
b_h1_init =  # fill in your bias
# EXTENDED
W_h1

# WEIGHTS/BIAS FOR SECOND NODE IN HIDDEN LAYER

# EXTENDED

# WEIGHTS/BIAS FOR OUTPUT NODE IN OUTPUT LAYER

# EXTENDED

# %%
# Compute the output of the hidden layer
# FIRST NODE
net_h1 =
h1 =
# SECOND NODE
net_h2 =
h2 =
# The output of the hidden layer is the input to the final layer.
print(h1, h2)

# %%
# INPUT FOR OUTPUT LAYER - combine h1 and h2
X_h =
# EXTENDED INPUT FOR OUTPUT LAYER----------------------------------------------------------
X_h_ext =

# Compute the final output, confirming that indeed the XOR function is implemented correctly.
net =
y =

print(y)
print(T)
