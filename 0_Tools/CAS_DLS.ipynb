# %% [markdown]
# ## Module 1 Notes
#
# - Check Google Colab
#
# - Use Jupiter Notebook to combine Documentation and Code
#
# https://jakevdp.github.io/PythonDataScienceHandbook/
#
# https://acg-team.github.io/docs/intro_to_python/
#
# https://wesmckinney.com/book/numpy-basics
#
# https://notebooklm.google.com/notebook/3f162d9d-351b-4742-ba69-81082c17b686
#
# https://code.visualstudio.com/
#
#
#
# Use timeit to check how much time has pass in between commands
#
# %timeit
# xml-> dictionary
#
# conversion of categories to number using dictionary
#
# Prepare for Module 2:
# - pandas
# - timeseries (measurement over time)
#
# e.g.
# Monitoring:
# - weather
# - hospital
# - stock price
#
# Detect:
# - outliers
#
# p-value / t-test
#
# basic maths
# - mean
# - average
# - normal distribution
#
# Use set to check uniqunes of lists
# len(set([...]))=len([...]) e.g. variance of a column
#
#
#
# Todo:
# Tabular print.
# pandas / numpy
# normalization: check the min and max, scale it down to float between 0 and 1

# %%
##tests variance
import pandas as pd

data = [[6, 9, 6], [9, 9, 9], [6, 9, 12]]

df = pd.DataFrame(data)

print(df.var())
# Out:
# 0    3.0
# 1    0.0
# 2    9.0
# dtype: float64
