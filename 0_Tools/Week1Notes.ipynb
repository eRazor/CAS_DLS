# %% [markdown]
# - Check Google Colab
#
# - Use Jupiter Notebook to combine Documentation and Code
#
#
#
# Prepare for Module 2:
# pandas
# timeseries
# measurement over time
# e.g.
# hospital monitoring weather
# stock price
# outliers
#
# basic maths
# mean
# average
# normal distribution
